# %% [markdown]
# # Linear Simple Regression
# > Documentation: https://scikit-learn.org/stable/modules/generated/sklearn.linear_model.LinearRegression.html

# %% [markdown]
# ## Setup

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from data_loader import load_data
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score, root_mean_squared_error

# %%
load_data("marinagrabelli/california-housing-train","../Data")
df = pd.read_csv('../Data/california_housing_train.csv')
df.head()
# Out:
# Dataset URL: https://www.kaggle.com/datasets/marinagrabelli/california-housing-train
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -114.31     34.19                15.0       5612.0          1283.0
# 1    -114.47     34.40                19.0       7650.0          1901.0
# 2    -114.56     33.69                17.0        720.0           174.0
# 3    -114.57     33.64                14.0       1501.0           337.0
# 4    -114.57     33.57                20.0       1454.0           326.0
#
#    population  households  median_income  median_house_value
# 0      1015.0       472.0         1.4936             66900.0
# 1      1129.0       463.0         1.8200             80100.0
# 2       333.0       117.0         1.6509             85700.0
# 3       515.0       226.0         3.1917             73400.0
# 4       624.0       262.0         1.9250             65500.0

# %% [markdown]
# ## Try total_rooms with total_bedrooms

# %% [markdown]
# ### Simple visualization

# %%
sns.relplot(data = df, x = 'total_rooms', y = 'total_bedrooms')

# %% [markdown]
# ### Prepare independent variable

# %%
x = np.array(df['total_rooms']).reshape(-1,1)

# %% [markdown]
# ### Prepare dependent variable

# %%
y = np.array(df['total_bedrooms']).reshape(-1, 1)

# %% [markdown]
# ### Split train and test data

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.20)

# %% [markdown]
# ### Train the model

# %%
reg = LinearRegression()
model = reg.fit(x_train, y_train)

# %%
model.coef_, model.intercept_
# Out:
# (array([[0.18104174]]), array([61.87661937]))

# %% [markdown]
# ### Evaluate the model

# %%
y_pred = model.predict(x_test)
mae = mean_absolute_error(y_true=y_test,y_pred=y_pred)
mse = mean_squared_error(y_true=y_test,y_pred=y_pred)
# rmse = mean_squared_error(y_true=y_test,y_pred=y_pred,squared=False)
rmse = root_mean_squared_error(y_true=y_test,y_pred=y_pred)
mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

print('MAE: {} MSE: {} RMSE: {} R^2 {}'.format(mae, mse, rmse, r2))
# Out:
# MAE: 100.13667537816575 MSE: 23083.6156955784 RMSE: 151.93293157040839 R^2 0.8703231994353764

# %% [markdown]
# ### Visualiza your result

# %%
plt.scatter(x_test, y_test)
plt.scatter(x_test, y_pred)

# %% [markdown]
# ## Try median income with median house value

# %% [markdown]
# ### simple visualization

# %%
sns.relplot(data = df, x = 'median_income', y = 'median_house_value')

# %% [markdown]
# ### Prepare independent variable

# %%
x = np.array(df['median_income']).reshape(-1,1)

# %% [markdown]
# ### Prepare dependent variable

# %%
y = np.array(df['median_house_value']).reshape(-1,1)

# %% [markdown]
# ### Split train and test data

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.20)

# %% [markdown]
# ### Train the model

# %%
reg = LinearRegression()
model = reg.fit(x_train, y_train)

# %% [markdown]
# ### Evaluate the model

# %%
y_pred = model.predict(x_test)
mae = mean_absolute_error(y_true=y_test,y_pred=y_pred)
mse = mean_squared_error(y_true=y_test,y_pred=y_pred)
rmse = root_mean_squared_error(y_true=y_test,y_pred=y_pred)
mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

print('MAE: {} MSE: {} RMSE: {} R^2 {}'.format(mae, mse, rmse, r2))
# Out:
# MAE: 62260.44743721343 MSE: 6991014375.368093 RMSE: 83612.28603122925 R^2 0.49812942814101513

# %% [markdown]
# ### Visualiza your result

# %%
model.coef_, model.intercept_
# Out:
# (array([[41629.89160505]]), array([45235.01508757]))

# %%
plt.scatter(x_test, y_test)
plt.scatter(x_test, y_pred)

# %% [markdown]
# ## Try households with population

# %% [markdown]
# ### simple visualization

# %%
sns.relplot(data = df, x = 'households', y = 'population')

# %% [markdown]
# ### Prepare independent variable

# %%
x = np.array(df['households']).reshape(-1,1)

# %% [markdown]
# ### Prepare dependent variable

# %%
y = np.array(df['population']).reshape(-1,1)

# %% [markdown]
# ### Split train and test data

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.20)

# %% [markdown]
# ### Train the model

# %%
reg = LinearRegression()
model = reg.fit(x_train, y_train)

# %%
model.coef_, model.intercept_
# Out:
# (array([[2.6776134]]), array([86.84333557]))

# %% [markdown]
# ### Evaluate the model

# %%
y_pred = model.predict(x_test)
mae = mean_absolute_error(y_true=y_test,y_pred=y_pred)
mse = mean_squared_error(y_true=y_test,y_pred=y_pred)
rmse = root_mean_squared_error(y_true=y_test,y_pred=y_pred)
mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

print('MAE: {} MSE: {} RMSE: {} R^2 {}'.format(mae, mse, rmse, r2))
# Out:
# MAE: 279.01812830591854 MSE: 238401.07573676962 RMSE: 488.2633262254801 R^2 0.8321359045968781

# %% [markdown]
# ### Visualiza your result

# %%
plt.scatter(x_test, y_test)
plt.scatter(x_test, y_pred)
